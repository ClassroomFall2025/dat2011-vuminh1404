# %%
# =====================================================
# ĐỀ TÀI: QUẢN LÝ NHÂN SỰ TÍNH LƯƠNG CÔNG TY RỒNG VIỆT
# Môn: DAT201 - Lập trình Python
# Học viên: ...........................................
# =====================================================

# ======================
# 1. KHAI BÁO CÁC HÀM
# ======================

def nhap_nhan_vien():
    print("=== Nhập danh sách nhân viên từ bàn phím và lưu vào file ===")
    # TODO: Viết mã nhập nhân viên và lưu file


def doc_va_xuat_danh_sach():
    print("=== Đọc thông tin nhân viên từ file và xuất danh sách ===")
    # TODO: Viết mã đọc file và in ra màn hình


def tim_theo_ma():
    print("=== Tìm và hiển thị nhân viên theo mã ===")
    # TODO: Viết mã tìm nhân viên theo mã nhập từ bàn phím


def xoa_theo_ma():
    print("=== Xóa nhân viên theo mã và cập nhật file dữ liệu ===")
    # TODO: Viết mã xóa nhân viên và ghi lại vào file


def cap_nhat_theo_ma():
    print("=== Cập nhật thông tin nhân viên theo mã và lưu vào file ===")
    # TODO: Viết mã cập nhật thông tin nhân viên


def tim_theo_khoang_luong():
    print("=== Tìm các nhân viên theo khoảng lương nhập từ bàn phím ===")
    # TODO: Viết mã lọc nhân viên theo mức thu nhập


def sap_xep_theo_ten():
    print("=== Sắp xếp nhân viên theo họ và tên ===")
    # TODO: Viết mã sắp xếp danh sách nhân viên theo tên


def sap_xep_theo_thu_nhap():
    print("=== Sắp xếp nhân viên theo thu nhập ===")
    # TODO: Viết mã sắp xếp danh sách theo thu nhập tăng/giảm


def xuat_top_5():
    print("=== Xuất 5 nhân viên có thu nhập cao nhất ===")
    # TODO: Viết mã lấy 5 nhân viên có thu nhập cao nhất


def thoat():
    print("Cảm ơn bạn đã sử dụng chương trình. Tạm biệt!")


# ======================
# 2. HÀM MENU CHÍNH
# ======================

def menu():
    while True:
        print("\n========== MENU QUẢN LÝ NHÂN VIÊN ==========")
        print("1. Nhập danh sách nhân viên và lưu vào file")
        print("2. Đọc và xuất danh sách nhân viên")
        print("3. Tìm nhân viên theo mã")
        print("4. Xóa nhân viên theo mã")
        print("5. Cập nhật thông tin nhân viên")
        print("6. Tìm nhân viên theo khoảng lương")
        print("7. Sắp xếp nhân viên theo họ tên")
        print("8. Sắp xếp nhân viên theo thu nhập")
        print("9. Xuất 5 nhân viên có thu nhập cao nhất")
        print("0. Thoát chương trình")
        print("============================================")

        chon = input("Nhập lựa chọn của bạn (0-9): ")

        if chon == '1':
            nhap_nhan_vien()
        elif chon == '2':
            doc_va_xuat_danh_sach()
        elif chon == '3':
            tim_theo_ma()
        elif chon == '4':
            xoa_theo_ma()
        elif chon == '5':
            cap_nhat_theo_ma()
        elif chon == '6':
            tim_theo_khoang_luong()
        elif chon == '7':
            sap_xep_theo_ten()
        elif chon == '8':
            sap_xep_theo_thu_nhap()
        elif chon == '9':
            xuat_top_5()
        elif chon == '0':
            thoat()
            break
        else:
            print("⚠️ Lựa chọn không hợp lệ, vui lòng nhập lại!")
# Out:
# ========== MENU QUẢN LÝ NHÂN VIÊN ==========
# 1. Nhập danh sách nhân viên và lưu vào file
# 2. Đọc và xuất danh sách nhân viên
# 3. Tìm nhân viên theo mã
# 4. Xóa nhân viên theo mã
# 5. Cập nhật thông tin nhân viên
# 6. Tìm nhân viên theo khoảng lương
# 7. Sắp xếp nhân viên theo họ tên
# 8. Sắp xếp nhân viên theo thu nhập
# 9. Xuất 5 nhân viên có thu nhập cao nhất
# 0. Thoát chương trình
# ...
# === Sắp xếp nhân viên theo thu nhập ===
#
# ========== MENU QUẢN LÝ NHÂN VIÊN ==========
# 1. Nhập danh sách nhân viên và lưu vào file
# 2. Đọc và xuất danh sách nhân viên
# 3. Tìm nhân viên theo mã
# 4. Xóa nhân viên theo mã
# 5. Cập nhật thông tin nhân viên
# 6. Tìm nhân viên theo khoảng lương
# 7. Sắp xếp nhân viên theo họ tên
# 8. Sắp xếp nhân viên theo thu nhập
# 9. Xuất 5 nhân viên có thu nhập cao nhất
# 0. Thoát chương trình
# ...
# === Nhập danh sách nhân viên từ bàn phím và lưu vào file ===
#
# ========== MENU QUẢN LÝ NHÂN VIÊN ==========
# 1. Nhập danh sách nhân viên và lưu vào file
# ...
